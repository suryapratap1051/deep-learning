# %%
import numpy as np
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\surya\\Downloads\\data-set\\placement.csv")

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
sns.scatterplot(x='cgpa', y='placement_exam_marks', hue='placed', data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='placement_exam_marks'>

# %%
X=df.iloc[:,0:2]

# %%
X
# Out:
#      cgpa  placement_exam_marks
# 0    7.19                  26.0
# 1    7.46                  38.0
# 2    7.54                  40.0
# 3    6.42                   8.0
# 4    7.23                  17.0
# ..    ...                   ...
# 995  8.87                  44.0
# 996  9.12                  65.0
# 997  4.89                  34.0
# 998  8.62                  46.0
# 999  4.90                  10.0
#
# [1000 rows x 2 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 995    1
# 996    1
# 997    0
# 998    1
# 999    1
# Name: placed, Length: 1000, dtype: int64

# %%
from sklearn.linear_model import Perceptron

# %%
p=Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-25.65,  -8.  ]])

# %%
p.intercept_
# Out:
# array([-15.])

# %%
pip install mlxtend
# Out:
# Collecting mlxtendNote: you may need to restart the kernel to use updated packages.
#
#   Using cached mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\surya\anaconda3\lib\site-packages (from mlxtend) (3.7.0)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\surya\anaconda3\lib\site-packages (from mlxtend) (1.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\surya\anaconda3\lib\site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\surya\anaconda3\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: setuptools in c:\users\surya\anaconda3\lib\site-packages (from mlxtend) (65.6.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\surya\anaconda3\lib\site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\surya\anaconda3\lib\site-packages (from mlxtend) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\surya\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\surya\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\surya\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\surya\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\surya\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\surya\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\surya\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\surya\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\surya\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\surya\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\surya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.22.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# C:\Users\surya\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
